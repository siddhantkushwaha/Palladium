# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantkushwaha/palladium/blob/master/samples/Palladium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install palladium-python

# %%
from palladium.chrome_custom import ChromeCustom

# %%
chrome = ChromeCustom(headless=True)

# %%
chrome.get('https://github.com/siddhantkushwaha')
chrome.save_screenshot('/content/test.png')

# %%
from IPython.display import Image
Image('test.png')
